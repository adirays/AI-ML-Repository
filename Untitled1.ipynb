# %%
a=['b','a',"t","s"]
a[1]="e"
a=a+['y']
a.append('1')
a.pop(4)
print(a)
# Out:
# ['b', 'e', 't', 's', '1']

# %%
list=[4,3,25,67,83,4,56]
list.sort()
print(list)
# Out:
# [3, 4, 4, 25, 56, 67, 83]
