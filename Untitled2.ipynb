# %%
person = {
    "name": "Aditya",
    "sem": 7,
    "city": "bengaluru"
}
print(person)
# Out:
# {'name': 'Aditya', 'sem': 7, 'city': 'bengaluru'}

# %%
word={}
word['h']='welcome'
word['H']='world'
print(word)
# Out:
# {'h': 'welcome', 'H': 'world'}

# %%
p={
    'react':1,
    'flutter':2
}
print(p)
# Out:
# {'react': 1, 'flutter': 2}

# %%
employees = {}
n = int(input("no. of employees? "))
for i in range(n):
    emp_no = input("Enter number: ")
    emp_name = input("Enter name: ")
    employees[emp_no] = emp_name  
print(employees)
# Out:
# no. of employees?  3
# Enter number:  1
# Enter name:  a
# Enter number:  2
# Enter name:  b
# Enter number:  3
# Enter name:  c
# {'1': 'a', '2': 'b', '3': 'c'}
