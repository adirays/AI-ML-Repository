# %%
total = 0
while True:
    x = float(input("enter a number:"))
    total+=x
    if total>300:
        break
print("sum =",total)
# Out:
# enter a number: 45
# enter a number: 23
# enter a number: 45
# enter a number: 76
# enter a number: 34
# enter a number: 123
# sum = 346.0

# %%
while True:
    x = float(input("enter a number:"))
    if (x==0):
        break
# Out:
# enter a number: 3
# enter a number: 5
# enter a number: 6
# enter a number: 8
# enter a number: 0

# %%
while True:
    x = input("enter a string:")
    if (x!="bon"):
        continue
        else
        print("Voyage")
        break
# Out:
# enter a string: hello
# enter a string: world
# enter a string: bon
# enter a string: hal

# %%
while True:
    x = input("enter a string:")
    if (x!="bon"):
        continue
    else:
        print("Voyage")
        break
